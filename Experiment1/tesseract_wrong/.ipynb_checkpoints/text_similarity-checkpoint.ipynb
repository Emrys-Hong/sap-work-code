# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import re
from collections import Counter

def shared_chars(s1, s2):
    return sum((Counter(s1) & Counter(s2)).values())

def levenshtein(seq1, seq2):  
    size_x = len(seq1) + 1
    size_y = len(seq2) + 1
    matrix = np.zeros ((size_x, size_y))
    for x in range(size_x):
        matrix [x, 0] = x
    for y in range(size_y):
        matrix [0, y] = y

    for x in range(1, size_x):
        for y in range(1, size_y):
            if seq1[x-1] == seq2[y-1]:
                matrix [x,y] = min(
                    matrix[x-1, y] + 1,
                    matrix[x-1, y-1],
                    matrix[x, y-1] + 1
                )
            else:
                matrix [x,y] = min(
                    matrix[x-1,y] + 1,
                    matrix[x-1,y-1] + 1,
                    matrix[x,y-1] + 1
                )
    return (matrix[size_x - 1, size_y - 1])

# %%
thailand = pd.read_excel('thailand_map.xlsx')
thailand
# Out:
#            Province                  District  Postcode
# 0     Amnat Charoen      Mueang Amnat Charoen     37000
# 1               NaN                 Chanunman     37210
# 2               NaN                Hua Taphan     37240
# 3               NaN                Lua Amnart     37000
# 4               NaN                     Phana     37180
# 5               NaN          Senangkhanikhorn     37290
# 6               NaN          Phathumratvongsa     37110
# 7          Province                  District  Postcode
# 8         Ang Thong          Mueang Ang Thong     14000
# 9               NaN                    Chaiyo     14140
# 10              NaN                    Pa Mok     14130
# 11              NaN                 Pho Thong     14120
# 12              NaN                     Samko     14160
# 13              NaN                 Sawaengha     14150
# 14              NaN           Wiset Chai Chan     14110
# 15         Province                  District  Postcode
# 16        Ayutthaya  Phra Nakhon Si Ayutthaya     13000
# 17              NaN                Ban Phraek     13240
# 18              NaN                  Bang Ban     13250
# 19              NaN                Bang Pa In     13160
# 20              NaN                Bang Pahan     13220
# 21              NaN   Bang Sai (อำเภอบางซ้าย)     13270
# 22              NaN    Bang Sai (อำเภอบางไทร)     13270
# 23              NaN             Lat Bua Luang     13230
# 24              NaN                  Maha Rat     13150
# 25              NaN              Nakhon Luang     13260
# 26              NaN                    Phachi     13140
# 27              NaN                  Phak Hai     13120
# 28              NaN                      Sena     13110
# 29              NaN                  Tha Ruea     13130
# ...             ...                       ...       ...
# 974             NaN                 Thap Than     61120
# 975        Province                  District  Postcode
# 976       Uttaradit          Mueang Uttaradit     53000
# 977             NaN                  Ban Khok     53180
# 978             NaN                   Fak Tha     53160
# 979             NaN                    Laplae     53130
# 980             NaN                   Nam Pat     53110
# 981             NaN                   Phichai     53120
# 982             NaN                   Tha Pla     53150
# 983             NaN           Thong Saen Khan     53230
# 984             NaN                      Tron     53140
# 985        Province                  District  Postcode
# 986            Yala               Mueang Yala     95000
# 987             NaN              Bannang Sata     95130
# 988             NaN                    Betong     95110
# 989             NaN                    Kabang     95120
# 990             NaN              Krong Pinang     95000
# 991             NaN                     Raman     95140
# 992             NaN                   Than To     95150
# 993             NaN                      Yaha     95120
# 994        Province                  District  Postcode
# 995        Yasothon           Mueang Yasothon     35000
# 996             NaN          Kham Khuean Kaeo     35110
# 997             NaN                  Kho Wang     35160
# 998             NaN                  Kut Chum     35140
# 999             NaN             Loeng Nok Tha     35120
# 1000            NaN           Maha Chana Chai     35130
# 1001            NaN                    Pa Tio     35150
# 1002            NaN                   Sai Mun     35170
# 1003            NaN              Thai Charoen     35120
#
# [1004 rows x 3 columns]

# %%
eng_thai_province = pd.read_excel('eng_thai_province.xlsx')
eng_thai_province.head()
# Out:
#   Province (changwat) จังหวัด
# 0               Krabi  กระบี่
# 1               Krabi  กระบี่
# 2               Krabi  กระบี่
# 3               Krabi  กระบี่
# 4               Krabi  กระบี่

# %%
eng_thai_dict = {}
for index in eng_thai_province.index:
    eng_thai_dict[eng_thai_province.loc[index, 'Province (changwat)']] = eng_thai_province.loc[index, 'จังหวัด']
eng_thai_dict['Bangkok'] = 'กรุงเทพมหานคร'
eng_thai_dict['Nongbua Lamphu'] = 'หนองบัวลำภู'
eng_thai_dict['Phangnga'] = 'พังงา'
eng_thai_dict['Prachinburi'] = 'ปราจีนบุรี'
eng_thai_dict['Si Saket'] = 'ศรีสะเกษ'
eng_thai_dict['Singburi'] = 'สิงห์บุรี'
eng_thai_dict['Suphanburi'] = 'สุพรรณบุรี'

# %%
import math
df = pd.DataFrame()
province = 'Amnat Charoen'
count = 0
for index in thailand.index:
    df1_dict = thailand.loc[index, 'Province':'Postcode'].to_dict()
    
    if str(df1_dict['Province']) == 'nan':
        df1_dict['province_in_thai'] = eng_thai_dict[province]
        df1_dict['Province'] = province
        if not math.isnan(df1_dict['Postcode']):
            df1 = pd.DataFrame(df1_dict, index=[str(df1_dict['Postcode'])] )
            df = pd.concat([df1,df])
            count += 1
    elif str(df1_dict['Province']) == 'Province':
        pass
    else:
        province = df1_dict['Province']
        df1_dict['province_in_thai'] = eng_thai_dict[province]
        if not math.isnan(df1_dict['Postcode']):
            df1 = pd.DataFrame(df1_dict, index=[ str(df1_dict['Postcode']) ] )
            df = pd.concat([df1, df])
        
        count += 1

# %%
df.to_excel('thailand_map.xls')

# %%
df.head()
# Out:
#               District  Postcode  Province province_in_thai
# 35120     Thai Charoen     35120  Yasothon            ยโสธร
# 35170          Sai Mun     35170  Yasothon            ยโสธร
# 35150           Pa Tio     35150  Yasothon            ยโสธร
# 35130  Maha Chana Chai     35130  Yasothon            ยโสธร
# 35120    Loeng Nok Tha     35120  Yasothon            ยโสธร

# %%
raw_txt = pd.read_excel('cleaned_up_raw_txt.xls')
raw_txt.head()
# Out:
#                                             AddressLine1 AddressLine2  \
# 1384   บ.เอสแอนด์เจ อินเตอร์เนชั่นแนล อินเดอร์ไพร 600...        องขาม
# 1353                                5 ม.11 ตำบลคูบางหลวง          NaN
# 10309  2 ห้อง259/1 ชั้น2 (ปัทมาคลินิค) เซ็นทรัลแอร์พอ...  ิดล ต.หายยา
# 10321                                  57 ม.4 ต.บ้านติ้ว          NaN
# 1025            บ.อินทรี อีโคไซเคิล 318 ม.2 ตำบลมะขามคู่          NaN
#
#       AddressLine3 Country code CustomerConfirmationNumber  \
# 1384           NaN                        TDPSE04201708179
# 1353           NaN                        TDPSL06201701278
# 10309          NaN                        TDPSE09201715809
# 10321          NaN                        TDPSE09201715797
# 1025           NaN                        TDPSL06201701159
#
#                                       Parcel Label Photo Recipient email  \
# 1384   https://dhl.fareye.co/img/2017-08-11/4/cust_15...
# 1353   https://dhl.fareye.co/img/2017-08-11/4/cust_15...
# 10309  https://dhl.fareye.co/img/2017-09-28/4/cust_15...
# 10321  https://dhl.fareye.co/img/2017-09-28/4/cust_15...
# 1025   https://dhl.fareye.co/img/2017-08-09/4/cust_15...
#
#       Recipient name Recipient phone Recipient state  Recipient zipcode  \
# 1384        รัตนาวลี       952507257          ชลบุรี              20230
# 1353     คุณดาวเรือง       947096619        ปทุมธานี              12140
# 10309      เพชรรัตน์       835709003       เชียงใหม่              50100
# 10321         ชุลีพร       910320092       เพชรบูรณ์              67110
# 1025      คุณวริศศรา       957408920           ระยอง              21180
#
#        Unnamed: 11                                     AddressLine1.1  \
# 1384          1384  บ.เอสแอนด์เจ อินเตอร์เนชั่นแนล อินเดอร์ไพร 600...
# 1353          1353                               5 ม.11 ตำบลคูบางหลวง
# 10309        10309  2 ห้อง259/1 ชั้น2 (ปัทมาคลินิค) เซ็นทรัลแอร์พอ...
# 10321        10321                                  57 ม.4 ต.บ้านติ้ว
# 1025          1025           บ.อินทรี อีโคไซเคิล 318 ม.2 ตำบลมะขามคู่
#
#                                                     text  อำเภอ District
# 1384   รัตนาวลี อารีกุล (65)           ว\nบ.เอสแอนด์เ...         ศรีราชา
# 1353   ม:\nNou:\n\nคุณดาวเรือง เจียกกระจ่าง\n\nบ้านเล...     ลาดหลุมแก้ว
# 10309  23.jacket ana\nเพชรรัตน์ กิตตินุสรณ์\n2 ห้อง25...  เมืองเชียงใหม่
# 10321  งา ae\n~\n\nนางสาวชุลีพร ฤทธิบุญ\n\n57 ม.4 ตเบ...         หล่มสัก
# 1025   กรุณาส่ง : คุณวริศศรา บุญโต / แผนกบัญชี-การเงิ...       นิคมพัฒนา

# %%
# # # created a dataset that use postcode as index
thai_province_list = set(df.loc[:,'province_in_thai'])
len(thai_province_list) ## it have 77 province
# Out:
# 77

# %%
def get_province_postcode(text, index):
    if len(str(text)) < 10:
        print ('text too short', index)
    postcodes = [int(float(s[:5])) for s in re.findall(r'-?\d+\.?\d*', text) if len(str(int(float(s[:5]))))>=5 and int(float(s[:5])) >= 0]
    for postcode in postcodes:
        try:
            province = df.at[str(postcode),'province_in_thai'][0] if len(df.at[str(postcode),'province_in_thai'][0]) > 1 else df.at[str(postcode),'province_in_thai'] # special indexing to get the value
            return (province)
            
        except Exception as e:
            return ('unable to locate province through possible postcode')
            
def get_province_levenshtein(text):         
    words = text.split()
    final_dict = {}        
    for word in words:
        # check the correct word that have a lot of common with the word
        word = purge(word)
        # loop through all the states and see which one get higher accuracy       
        dict_score = defaultdict(lambda: 20)

        for province in thai_province_list:
            purged_province = purge(province)
            
            if shared_chars(word, purged_province) >= 2:
                if purged_province[:2] in word:
                    word_cut = word[word.find(purged_province[:2]):]
                    if purged_province[-2:] in word_cut:
                        word_cut = word_cut[:word.find(purged_province[-2:])]
                elif purged_province[1] in word:
                    word_cut = word[word.find(purged_province[0])+1:]
                elif purged_province[0] in word:
                    word_cut = word[word.find(purged_province[0]):]
                else:
                    word_cut = word
                score = levenshtein(purged_province, word_cut)/len(word_cut)
#                 print(levenshtein(province, word_cut)/len(word_cut), word_cut,province)
                dict_score[province] = min(score, dict_score[province])
        
        correct_province = {k:v for k,v in dict_score.items() if v == min(dict_score.values())}
        final_dict = {**final_dict, **correct_province}
    return list( {k:v for k,v in final_dict.items() if v == min(final_dict.values())}.keys() )
        
            
def purge(string):
    new_string = ''
    delete_list = [b'\xe0\xb8\xb1',b'\xe0\xb8\xb3',b'\xe0\xb8\xb4',b'\xe0\xb8\xb5',b'\xe0\xb8\xb6',b'\xe0\xb8\xb7',b'\xe0\xb8\xb8',b'\xe0\xb8\xb9',b'\xe0\xb8\xba',b'\xe0\xb9\x87',b'\xe0\xb9\x88',b'\xe0\xb9\x89',b'\xe0\xb9\x8a',b'\xe0\xb9\x8b',b'\xe0\xb9\x8c',b'\xe0\xb9\x8d',b'\xe0\xb9\x8e']
    for char in string:
        if char.encode('utf') not in delete_list:
            new_string += char
    return new_string

# %%
df.at['35120', 'province_in_thai'][0]
# Out:
# 'ยโสธร'

# %%
word = purge('จ.ภเก็ต'); province = purge('ภเกต')
if shared_chars(word, province) >= 2:
    if province[:2] in word:
        word = word[word.find(province[:2]):]
    elif province[1] in word:
        word = word[word.find(province[0])+1:]
    elif province[0] in word:
        word = word[word.find(province[0]):]
    score = levenshtein(province, word)/len(word)

# %% [markdown]
# # 105 out of 196 valid ones are correct

# %%
postcode = []
format_wrong=0;format_right=0
for index in raw_txt.index:
    try:
        text = raw_txt.get_value(index,'text')
        postcode.append([get_province_postcode(text,index),raw_txt.get_value(index,'Recipient state'),index])
        format_right+=1
    except Exception:
        postcode.append(['text format wrong',raw_txt.get_value(index,'Recipient state'),index])
        format_wrong+=1
print(format_right)
print(postcode)
print(len(raw_txt))
# Out:
# 170
# [['unable to locate province through possible postcode', 'ชลบุรี', 1384], ['ปทุมธานี', 'ปทุมธานี', 1353], ['unable to locate province through possible postcode', 'เชียงใหม่', 10309], ['unable to locate province through possible postcode', 'เพชรบูรณ์', 10321], ['ระยอง', 'ระยอง', 1025], ['unable to locate province through possible postcode', 'ศรีสะเกษ', 10296], ['ปราจีนบุรี', 'ปราจีนบุรี', 10255], ['นครราชสีมา', 'นครราชสีมา', 10241], ['กรุงเทพมหานคร', 'กรุงเทพ', 10240], ['นครปฐม', 'นครปฐม', 10254], [None, 'อุตรดิตถ์', 10268], ['กรุงเทพมหานคร', 'กรุงเทพ', 10297], [None, 'สกลนคร', 1018], ['กรุงเทพมหานคร', 'กรุงเทพ', 1030], ['กรุงเทพมหานคร', 'กรุงเทพ', 1024], ['พระนครศรีอยุธยา', 'อยุธยา', 1150], ['กรุงเทพมหานคร', 'กรุงเทพ', 10693], ['กรุงเทพมหานคร', 'กรุงเทพ', 10320], [None, 'ปทุมธานี', 10308], ['กรุงเทพมหานคร', 'กรุงเทพ', 1420], ['กรุงเทพมหานคร', 'กรุงเทพ', 1422], ['unable to locate province through possible postcode', 'สมุทรสาคร', 1224], ['สมุทรสาคร', 'สมุทรสาคร', 10242], ['กรุงเทพมหานคร', 'กรุงเทพ', 10256], [None, 'ภูเก็ต', 10294], ['unable to locate province through possible postcode', 'อยุธยา', 1033], ['กรุงเทพมหานคร', 'ก
', 'ปัตตานี', 10557], ['กรุงเทพมหานคร', 'กรุงเทพ', 10225], [None, 'ชลบุรี', 1069], ['unable to locate province through possible postcode', 'ขอนแก่น', 1082], ['นนทบุรี', 'นนทบุรี', 1096], ['สมุทรปราการ', 'สมุทรปราการ', 10437], ['นนทบุรี', 'นนทบุรี', 10347], ['กรุงเทพมหานคร', 'กรุงเทพ', 10435], ['ปทุมธานี', 'ปทุมธานี', 10780], ['unable to locate province through possible postcode', 'ชลบุรี', 1094], [None, 'อุบลราชธานี', 1269], ['ปราจีนบุรี', 'ปราจีนบุรี', 10622], ['unable to locate province through possible postcode', 'นครปฐม', 1334], ['กรุงเทพมหานคร', 'กรุงเทพ', 10439], ['กรุงเทพมหานคร', 'กรุงเทพ', 1305], ['กรุงเทพมหานคร', 'อุดรธานี', 1339], ['unable to locate province through possible pos ...
# 170
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %% [markdown]
# ## reasons for error:
# 1. do not have the zip code in the database
# 2. tesseract processing 50100 to 506106

# %% [markdown]
# # 67 correct out of 139

# %%
stat_dict = {}
format_right = 0; format_wrong = 0
for index in raw_txt.index:
    try:
        text = raw_txt.get_value(index,'text')
        stat_dict[index] = [get_province_levenshtein(text),raw_txt.get_value(index,'Recipient state')]
        format_right += 1
    except Exception:
#         stat_dict[index] = ['text format wrong',raw_txt.loc[index,'Recipient state']]
        format_wrong += 1
print(stat_dict)
print(len(stat_dict))
# Out:
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# {1384: [['ชลบุรี'], 'ชลบุรี'], 1353: [['ปทุมธานี'], 'ปทุมธานี'], 10309: [['เชียงใหม่'], 'เชียงใหม่'], 10321: [['เพชรบูรณ์'], 'เพชรบูรณ์'], 1025: [['ระยอง'], 'ระยอง'], 10296: [['ศรีสะเกษ'], 'ศรีสะเกษ'], 10255: [['ปราจีนบุรี'], 'ปราจีนบุรี'], 10241: [['นครราชสีมา'], 'นครราชสีมา'], 10240: [['ราชบุรี'], 'กรุงเทพ'], 10254: [['ลำพูน'], 'นครปฐม'], 10268: [['ตาก'], 'อุตรดิตถ์'], 10297: [['น่าน'], 'กรุงเทพ'], 1018: [['ตราด'], 'สกลนคร'], 1030: [['น่าน'], 'กรุงเทพ'], 1024: [['หนองคาย', 'แม่ฮ่องสอน'], 'กรุงเทพ'], 1150: [['ลำพูน'], 'อยุธยา'], 10693: [['ตราด'], 'กรุงเทพ'], 10320: [['นครราชสีมา'], 'กรุงเทพ'], 10308: [['ปทุมธานี'], 'ปทุมธานี'], 1420: [['ชัยนาท'], 'กรุงเทพ'], 1422: [['หนองคาย'], 'กรุงเทพ'], 1224: [['พิจิตร'], 'สมุทรสาคร'], 10242: [['สมุทรสาคร'], 'สมุทรสาคร'], 10256: [['เลย'], 'กรุงเทพ'], 10294: [['ภูเก็ต'], 'ภูเก็ต'], 1033: [['พระนครศรีอยุธยา'], 'อยุธยา'], 1153: [['ตราด'], 'กรุงเทพ'], 1423: [['เพชรบุรี'], 'กรุงเทพ'], 1386: [['กาญจนบุรี'], 'กาญจนบุรี'], 1382: [['อุดรธานี'], 'อุดรธานี'], 10327: [['สมุทรปราการ'], 'สมุทรปราการ'], 1427: [['นครศรีธรรมราช'], 'นครศรีธรรมราช'], 1037: [['ตาก', 'เลย', 'กระบี่'], 'กรุงเทพ'], 10290: [['ชลบุรี'], 'ชลบุรี'], 10247: [['สงขลา'], 'สงขลา'], 10509: [['ร้อยเอ็ด'], 'ร้อยเอ็ด'], 10508: [['อำนาจเจริญ'], 'กรุงเทพ'], 10252: [['เลย', 'ชัยภูมิ'], 'กรุงเทพ'], 10291: [['ยโสธร'], 'ยโสธร'], 10285: [['เชียงใหม่'], 'เชียงใหม่'], 1426: [['ตราด'], 'ตราด'], 10440: [['ชลบุรี'], 'ชลบุรี'], 10326: [['กรุงเทพมหานคร'], 'กรุงเทพมหานคร'], 1383: [['ตรัง', 'นนทบุรี'], 'นนทบุรี'], 1381: [['สมุทรปราการ'], 'สมุทรปราการ'], 10324: [['นนทบุรี'], 'นนทบุรี'], 1418: [['นนทบุรี'], 'นนทบุรี'], 10318: [['นครพนม'], 'นครพนม'], 1356: [['เลย'], 'เลย'], 10293: [['ตาก', 'น่าน'], 'กรุงเทพ'], 10287: [['พังงา', 'ตราด'], 'ชลบุรี'], 10244: [['สุรินทร์', 'ภูเก็ต'], 'สมุทรปราการ'], 10278: [['ลพบุรี'], 'ลพบุรี'], 10279: [['กำแพงเพชร'], 'กำแพงเพชร'], 10251: [['ชุมพร'], 'กรุงเทพ'], 10286: [['ชลบุรี', 'ตาก', 'น่าน'], 'กรุงเทพ'], 10292: [['ตรัง'], 'เพชรบุรี'], 1182: [['สมุทรปราการ'], 'สมุทรปราการ'], 1425: [['อุดรธานี'], 'อุดรธานี'], 1419: [['นนทบุรี'], 'นนทบุรี'], 10325: [['ภูเก็ต'], 'ภูเก็ต'], 10418: [['อุดรธานี', 'อุตรดิตถ์', 'กาฬสินธุ์'], 'กรุงเทพ'], 1318: [['แพร่'], 'กรุงเทพ'], 10829: [['ตราด'], 'กรุงเทพ'], 10034: [['จันทบุรี'], 'จันทบุรี'], 10237: [['ระยอง'], 'ระยอง'], 1047: [['สมุทรปราการ'], 'สมุทรปราการ'], 1084: [['ราชบุรี'], 'กรุงเทพ'], 10425: [['ยะลา'], 'อยุธยา'], 1092: [['ปทุมธานี'], 'ปทุมธานี'], 1086: [['อุบลราชธานี'], 'อุบลราชธานี'], 10779: [['จันทบุรี'], 'กรุงเทพ'], 1252: [['อุดรธานี'], 'อุุดรธานี'], 1078: [['หนองคาย'], 'ชลบุรี'], 1087: [['สระบุรี'], 'สระบุรี'], 1093: [['อุดรธานี'], 'อุดรธานี'], 1326: [['ปทุมธานี'], 'ปทุมธานี'], 10783: [['สมุทรปราการ'], 'สมุทรปราการ'], 1083: [['นนทบุรี'], 'นนทบุรี'], 1040: [['ราชบุรี'], 'กรุงเทพ'], 1295: [['สมุทรปราการ'], 'สมุทรปราการ'], 10224: [['นครศรีธรรมราช'], 'นครศรีธรรมราช'], 10230: [['ลำพูน'], 'สงขลา'], 10556: [['กรุงเทพมหานคร'], 'กรุงเทพ'], 10557: [['ตาก'], 'ปัตตานี'], 10225: [['บุรีรัมย์'], 'กรุงเทพ'], 1069: [['ชลบุรี'], 'ชลบุรี'], 1082: [['ขอนแก่น'], 'ขอนแก่น'], 1096: [['ยโสธร', 'ระนอง', 'ร้อยเอ็ด'], 'นนทบุรี'], 10437: [['สมุทรปราการ'], 'สมุทรปราการ'], 10347: [['นนทบุรี'], 'นนทบุรี'], 10435: [['ชุมพร'], 'กรุงเทพ'], 10780: [['ปทุมธานี'], 'ปทุมธานี'], 1094: [['ชลบุรี'], 'ชลบุรี'], 1269: [['อุบลราชธานี'], 'อุบลราชธานี'], 10622: [['ปราจีนบุรี'], 'ปราจีนบุรี'], 1334: [['นครปฐม'], 'นครปฐม'], 10439: [['ระนอง'], 'กรุงเทพ'], 1305: [['น่าน'], 'กรุงเทพ'], 1339: [['หนองคาย'], 'อุดรธานี'], 10149: [['กาญจนบุรี'], 'กรุงเทพ'], 1073: [['ชลบุรี'], 'ชลบุรี'], 1259: [['ฉะเชิงเทรา'], 'ฉะเชิงเทรา'], 1072: [['สงขลา'], 'สงขลา'], 1066: [['พัทลุง'], 'ชลบุรี'], 1304: [['กรุงเทพมหานคร'], 'กรุงเทพ'], 10438: [['พิษณุโลก'], 'พิษณุโลก'], 10837: [['ปทุมธานี'], 'ปทุมธานี'], 1070: [['ภูเก็ต'], 'ภูเก็ต'], 1058: [['อุบลราชธานี'], 'อุบลราชธานี'], 1272: [['ชุมพร', 'ชลบุรี', 'เชียงราย', 'ราชบุรี', 'บุรีรัมย์'], 'กรุงเทพ'], 10228: [['ลำพูน'], 'บึงกาฬ'], 1267: [['เลย', 'ตราด'], 'กรุงเทพ'], 1298: [['น่าน'], 'อยุธยา'], 1059: [['ลำปาง', 'ภ ...
# 170

# %% [markdown]
# # 110 text format wrong and 35 None

# %%
address = list()

for index in raw_txt.index:
    
    text = raw_txt.get_value(index,'text')
    if get_province_postcode(text, index) == 'unable to locate province through possible postcode' or get_province_postcode(text, index) == None:
        
        text = raw_txt.get_value(index,'text')
        address.append([get_province_levenshtein(text),raw_txt.get_value(index,'Recipient state'), index])
    else:
        try:
            text = raw_txt.get_value(index,'text')
            address.append([get_province_postcode(text,index),raw_txt.get_value(index,'Recipient state'),index])
        except Exception:
            address.append(['err', index])
    
# print(address)
print(len(address))
count = 0
print(address)
# Out:
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /Users/i351707/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# 170
# [[['หนองคาย'], 'ชลบุรี', 1384], ['ปทุมธานี', 'ปทุมธานี', 1353], [['เชียงใหม่'], 'เชียงใหม่', 10309], [['เพชรบุรี', 'เพชรบูรณ์'], 'เพชรบูรณ์', 10321], ['ระยอง', 'ระยอง', 1025], [['ศรีสะเกษ'], 'ศรีสะเกษ', 10296], ['ปราจีนบุรี', 'ปราจีนบุรี', 10255], ['นครราชสีมา', 'นครราชสีมา', 10241], ['กรุงเทพม
คร', 'กรุงเทพ', 10829], ['จันทบุรี', 'จันทบุรี', 10034], ['ระยอง', 'ระยอง', 10237], ['กรุงเทพมหานคร', 'สมุทรปราการ', 1047], ['กรุงเทพมหานคร', 'กรุงเทพ', 1084], ['พระนครศรีอยุธยา', 'อยุธยา', 10425], ['ปทุมธานี', 'ปทุมธานี', 1092], ['อุบลราชธานี', 'อุบลราชธานี', 1086], ['กรุงเทพมหานคร', 'กรุงเทพ', 10779], ['อุดรธานี', 'อุุดรธานี', 1252], [['หนองคาย'], 'ชลบุรี', 1078], ['สระบุรี', 'สระบุรี', 1087], ['อุดรธานี', 'อุดรธานี', 1093], [['ปทุมธานี'], 'ปทุมธานี', 1326], ['สมุทรปราการ', 'สมุทรปราการ', 10783], [['จันทบุรี'], 'นนทบุรี', 1083], ['กรุงเทพมหานคร', 'กรุงเทพ', 1040], ['สมุทรปราการ', 'สมุทรปราการ', 1295], ['นครศรีธรรมราช', 'นครศรีธรรมราช', 10224], [['ลำพูน'], 'สงขลา', 10230], [['กรุงเทพมหานคร'], 'กรุงเทพ', 10556], ['ปัตตานี', 'ปัตตานี', 10557], ['กรุงเทพมหานคร', 'กรุงเทพ', 10225], [['ชลบุรี'], 'ชลบุรี', 1069], [['ขอนแก่น'], 'ขอนแก่น', 1082], ['นนทบุรี', 'นนทบุรี', 1096], ['สมุทรปราการ', 'สมุทรปราการ', 10437], ['นนทบุรี', 'นนทบุรี', 10347], ['กรุงเทพมหานคร', 'กรุงเทพ', 10435], ['ปทุมธานี', 'ปทุมธานี', 10780], [['ชลบุรี'], 'ชลบุรี', 1094], [['อุบลราชธานี'], 'อุบลราชธานี', 1269], ['ปราจีนบุรี', 'ปราจีนบุรี', 10622], [['นครปฐม'], 'นครปฐม', 1334], ['กรุงเทพมหานคร', 'กรุงเทพ', 10439], ['กรุงเทพมหานคร', 'กรุงเทพ', 1305], ['กรุงเทพมหานคร', 'อุดรธานี', 1339], [['กาญจนบุรี'], 'กรุงเทพ', 10149], [['ชลบุรี'], 'ชลบุรี', 1073], [['ฉะเชิงเทรา'], 'ฉะเชิงเทรา', 1259], [['สงขลา'], 'สงขลา', 1072], [['พัทลุง'], 'ชลบุรี', 1066], [['กรุงเทพมหานคร'], 'กรุงเทพ', 1304], ['พิษณุโลก', 'พิษณุโลก', 10438], ['ปทุมธานี', 'ปทุมธานี', 10837], ['ภูเก็ต', 'ภูเก็ต', 1070], ['อุบลราชธานี', 'อุบลราชธานี', 1058], ['กรุงเทพมหานคร', 'กรุงเทพ', 1272], [['ลำพูน'], 'บึงกาฬ', 10228], ['กรุงเทพมหานคร', 'กรุงเทพ', 1267], [['น่าน'], 'อยุธยา', 1298], [['ลำปาง', 'ภูเก็ต', 'พะเยา'], 'สมุทรปราการ', 1059], [['ระนอง', 'ระยอง', 'พัทลุง'],  ...

# %% [markdown]
# 10516, 1389, 10268, 1304,  tesseract unable to catch information or wrong information for the zip code
# 1047 have confusing numbers as postcode have two address
